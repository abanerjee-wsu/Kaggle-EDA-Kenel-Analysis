# %%
#Minimal Example
#===============
#Generating a square wordcloud from the kagge kernel titles.
#"""

#import os.path
from wordcloud import WordCloud
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#d = os.path.dirname(os.path.abspath("__file__"))

#Read the csv file & filter title
kernel = pd.read_csv('kernels_new_combined.csv', sep = '|')
titleColumn = kernel.title.astype(str)
title = titleColumn.to_string()

# Read the whole text.
#text = open(path.join(d, 'title.txt')).read()

# Generate a word cloud image
#wordcloud = WordCloud().generate(kernel.title)

# Display the generated image:
# the matplotlib way:

#plt.imshow(wordcloud, interpolation='bilinear')
#plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=50).generate(text2)
plt.figure(figsize=(10, 8), dpi=80)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# The pil way (if you don't have matplotlib)
# image = wordcloud.to_image()
# image.show()

# %%
text
# Out:
# 0                      Data ScienceTutorial for Beginners
# 1                    Be my guest - Recruit Restaurant EDA
# 2               What do Kagglers say about Data Science ?
# 3       Comprehensive Python and D3.js Favorita analytics
# 4              Comprehensive data exploration with Python
# 5                Feature Selection and Data Visualization
# 6                 Machine Learning Tutorial for Beginners
# 7         Ghastly Network and D3.js Force-directed graphs
# 8              Speech representation and data exploration
# 9       More Effective Ridge LGBM Script (LB 0.44341) - 2
# 10                     Playing with maps while learning R
# 11      Despeckling Synthetic Aperture Radar (SAR) Ima...
# 12                  Detailed Spooky Fun EDA and Modelling
# 13                         Seaborn Tutorial for Beginners
# 14                                   5 Day Data Challenge
# 15              Exploring Youtube Trending Statistics EDA
# ...
